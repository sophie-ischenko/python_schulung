# %% [markdown]
# # Tag 5: Der große Praxis-Marathon (Wochen-Review)
#
# **Zeitrahmen:** 4 Stunden Vormittag (z. B. 09:00 – 13:00 Uhr)
# **Plattform:** Google Colab / Jupyter
# **Fokus:** Ein reiner Praxis- und Festigungstag ohne neuen theoretischen Input. Die erste Hälfte des Kurses wird durch ein intensives Aufgabenspektrum von 80 Programmier- und Debugging-Aufgaben (genau 20 Aufgaben pro Wochenthema) abgeschlossen.
#
# ## Zeitplan: Übersicht
#
# - **09:00 – 09:15 Uhr:** Briefing & Ablauf — Erklärung der "Practice Arena": Die Teilnehmenden arbeiten selbstständig oder in Zweierteams. Sie können die Aufgaben nacheinander lösen oder nach Themengebieten vorgehen. Der Trainer unterstützt individuell.
# - **09:15 – 11:00 Uhr:** Coding-Marathon – Phase 1
# - *11:00 – 11:15 Uhr:* Pause
# - **11:15 – 12:45 Uhr:** Coding-Marathon – Phase 2
# - **12:45 – 13:00 Uhr:** Wochen-Review & Ausblick — Sicherung der Notebooks und Ausblick auf Woche 2 (Logik, Schleifen, Funktionen).
#
# > Jede Aufgabe steht in einer eigenen Code-Zelle und kann unabhängig ausgeführt werden.

# %% [markdown]
# ## Thema 1: Grundlagen, Variablen, Input & Mathematik (40 Aufgaben)
#
# ### 20 Einfache Aufgaben

# %%
# Aufgabe 1: Variable erstellen
abteilung = "Support"
print(abteilung)

# %%
# Aufgabe 2: Ganzzahl anlegen
anzahl_monitore = 14
print(anzahl_monitore)

# %%
# Aufgabe 3: Dezimalzahl anlegen
leitung_speed = 940.5
print(leitung_speed)

# %%
# Aufgabe 4: Wahrheitswert anlegen
ping_erfolgreich = True
print(ping_erfolgreich)

# %%
# Aufgabe 5: Print-Ausgabe
print("Systemstart...")

# %%
# Aufgabe 6: Einfacher Input
vorname = input("Vorname: ")
print(vorname)

# %%
# Aufgabe 7: Addition
print(40 + 2)

# %%
# Aufgabe 8: Subtraktion
print(50 - 10)

# %%
# Aufgabe 9: Multiplikation
print(6 * 7)

# %%
# Aufgabe 10: Division
print(100 / 4)

# %%
# Aufgabe 11: Datentyp prüfen
print(type(4.5))

# %%
# Aufgabe 12: Mehrfache Zuweisung
x, y = 5, 10
print(x, y)

# %%
# Aufgabe 13: String-Konvertierung
print(str(100))

# %%
# Aufgabe 14: Ganzzahl-Konvertierung
print(int("50"))

# %%
# Aufgabe 15: Dezimalzahl-Konvertierung
print(float("3.14"))

# %%
# Aufgabe 16: Wahrheitswert-Ausgabe
online = False
print(online)

# %%
# Aufgabe 17: Kommentar schreiben
# Das ist ein Kommentar

# %%
# Aufgabe 18: Zusammenfügen
a = "IT"
b = "Support"
print(a + b)

# %%
# Aufgabe 19: Variable überschreiben
wert = 1
wert = 2
print(wert)

# %%
# Aufgabe 20: Leerer String
notiz = ""
print(repr(notiz))

# %% [markdown]
# ### 20 Mittlere Aufgaben

# %%
# Aufgabe 21: Dynamischer Addierer
z1 = int(input("Zahl 1: "))
z2 = int(input("Zahl 2: "))
print(z1 + z2)

# %%
# Aufgabe 22: Uptime in Minuten
tage = int(input("Tage: "))
print(tage * 24 * 60)

# %%
# Aufgabe 23: Modulo-Berechnung
print(19 % 4)

# %%
# Aufgabe 24: Ganzzahlige Division
print(37 // 5)

# %%
# Aufgabe 25: Server-Kapazität
belegt = int(input("Belegt in GB: "))
print(f"Frei: {500 - belegt} GB")

# %%
# Aufgabe 26: Potenzierung
print(2 ** 16)

# %%
# Aufgabe 27: Lizenz-Budget
user = int(input("User-Anzahl: "))
print(user * 85.50)

# %%
# Aufgabe 28: Netto-Rechner
brutto = float(input("Brutto: "))
print(brutto / 1.19)

# %%
# Aufgabe 29: Durchschnitts-RAM
pc1 = int(input("PC 1 RAM: "))
pc2 = int(input("PC 2 RAM: "))
pc3 = int(input("PC 3 RAM: "))
print((pc1 + pc2 + pc3) / 3)

# %%
# Aufgabe 30: Mehrwertsteuer-Anteil
netto = float(input("Netto: "))
print(netto * 0.19)

# %%
# Aufgabe 31: f-String Profile
n = input("Name: ")
r = input("Rolle: ")
print(f"Benutzer: {n}, Rolle: {r}")

# %%
# Aufgabe 32: Datenübertragung
groesse = float(input("Dateigröße (MB): "))
print(f"Dauer: {groesse / 10} Sekunden")

# %%
# Aufgabe 33: Zahl quadrieren
zahl = int(input("Zahl: "))
print(zahl ** 2)

# %%
# Aufgabe 34: IP-Viertel addieren
o1 = int(input("Oktett 1: "))
o2 = int(input("Oktett 2: "))
o3 = int(input("Oktett 3: "))
o4 = int(input("Oktett 4: "))
print(o1 + o2 + o3 + o4)

# %%
# Aufgabe 35: Ticket-Stunden
tickets = int(input("Anzahl Tickets: "))
print((tickets * 45) / 60)

# %%
# Aufgabe 36: Arbeitszeit-Rechner
stunden = float(input("Stunden: "))
print(stunden * 22.50)

# %%
# Aufgabe 37: Rest-Budget
ausgaben = float(input("Ausgaben: "))
print(10000 - ausgaben)

# %%
# Aufgabe 38: Drucker-Seiten
seiten = int(input("Seiten: "))
print(seiten / 30)

# %%
# Aufgabe 39: Prozentuale Auslastung
belegt = float(input("Belegt (GB): "))
print((belegt / 2000) * 100)

# %%
# Aufgabe 40: Tage bis Patchday
tage = int(input("Tage: "))
print(tage * 24)

# %% [markdown]
# ---
# ## Thema 2: String-Manipulation & Slicing (40 Aufgaben)
#
# ### 20 Einfache Aufgaben

# %%
# Aufgabe 41: Erstes Zeichen
print("Server"[0])

# %%
# Aufgabe 42: Zweites Zeichen
print("Port"[1])

# %%
# Aufgabe 43: Letztes Zeichen
print("Switch"[-1])

# %%
# Aufgabe 44: Vorletztes Zeichen
print("Router"[-2])

# %%
# Aufgabe 45: Teil-Schnitt 1
print("Netzwerk"[:3])

# %%
# Aufgabe 46: Teil-Schnitt 2
print("Client"[-4:])

# %%
# Aufgabe 47: Länge
print(len("Passwort123"))

# %%
# Aufgabe 48: Großbuchstaben
print("update".upper())

# %%
# Aufgabe 49: Kleinbuchstaben
print("DATABASE".lower())

# %%
# Aufgabe 50: Leerzeichen vorn/hinten weg
print("  test  ".strip())

# %%
# Aufgabe 51: Anfang prüfen
print("FW-01".startswith("FW"))

# %%
# Aufgabe 52: Ende prüfen
print("logo.png".endswith(".png"))

# %%
# Aufgabe 53: Zeichen finden
print("SN-XYZ".find("X"))

# %%
# Aufgabe 54: String vervielfachen
print("Fehler! " * 3)

# %%
# Aufgabe 55: Zeichen zählen
print("Heidelberg".count("e"))

# %%
# Aufgabe 56: F-String Name
name = "Sven"
print(f"Hallo {name}")

# %%
# Aufgabe 57: Datentyp ermitteln
print(type("123"))

# %%
# Aufgabe 58: Konkatenation
print("IP-" + "Config")

# %%
# Aufgabe 59: String mit Zeilenumbruch
print("Zeile1\nZeile2")

# %%
# Aufgabe 60: Tabulator
print("Spalte1\tSpalte2")

# %% [markdown]
# ### 20 Mittlere Aufgaben

# %%
# Aufgabe 61: Zeichen ersetzen
print("192.168.0.1".replace(".", "-"))

# %%
# Aufgabe 62: String splitten
print("Maus,Tastatur,Monitor".split(","))

# %%
# Aufgabe 63: Domain extrahieren
email = "user@firma.de"
print(email[5:])

# %%
# Aufgabe 64: Schnitt Mitte
sn = "SN-123-ABC"
print(sn[3:6])

# %%
# Aufgabe 65: Rückwärts ausgeben
print("Informatik"[::-1])

# %%
# Aufgabe 66: Case-Insensitive Zählung
print("Enterprise-Server".lower().count("e"))

# %%
# Aufgabe 67: Pfad korrigieren
print("C:/Temp/install.log".replace("/", "\\\\"))

# %%
# Aufgabe 68: Nur Zahlen prüfen
print("90210".isdigit())

# %%
# Aufgabe 69: Prüfen auf Kleinbuchstaben (Recherche)
# Gesuchte Methode: .islower()
print("admin".islower())

# %%
# Aufgabe 70: Formatierte Ausgabe IP
net, host = "192.168", "25"
print(f"IP: {net}.1.{host}")

# %%
# Aufgabe 71: Teilungs-Check
print("C:\\Windows\\System32".split("\\"))

# %%
# Aufgabe 72: Wort suchen
print("ERROR" in "Status: [INFO] OK")

# %%
# Aufgabe 73: Zeichen überspringen
print("ABCDEFGHIJ"[::2])

# %%
# Aufgabe 74: In Großbuchstaben umwandeln
host = input("Host: ")
print(host.upper())

# %%
# Aufgabe 75: Strip & Replace
print("  [WARN]  ".strip().replace("WARN", "ALERT"))

# %%
# Aufgabe 76: In Titelformat wandeln
print("max mustermann".title())

# %%
# Aufgabe 77: Anzahl der Wörter
satz = "Das System läuft wieder"
print(len(satz.split()))

# %%
# Aufgabe 78: Suffix-Verifizierung (Recherche)
datei = "data.zip"
print(datei.endswith((".zip", ".rar")))

# %%
# Aufgabe 79: Sonderzeichen entfernen
print("A;B;C;D".replace(";", ""))

# %%
# Aufgabe 80: String-Zentrierung (Recherche)
# Gesuchte Methode: .center()
print("STATUS".center(20, "-"))

# %% [markdown]
# ---
# ## Thema 3: Listen & Listen-Methoden (40 Aufgaben)
#
# ### 20 Einfache Aufgaben

# %%
# Aufgabe 81: Liste erstellen
farben = ["Rot", "Grün", "Blau"]
print(farben)

# %%
# Aufgabe 82: Erstes Element
print(["A", "B", "C"][0])

# %%
# Aufgabe 83: Letztes Element
print(["A", "B", "C"][-1])

# %%
# Aufgabe 84: Länge
print(len(["A", "B"]))

# %%
# Aufgabe 85: Element anhängen
farben = ["Rot", "Grün", "Blau"]
farben.append("Gelb")
print(farben)

# %%
# Aufgabe 86: Wert überschreiben
werte = ["X", "Y"]
werte[0] = "A"
print(werte)

# %%
# Aufgabe 87: Element löschen
farben = ["Rot", "Grün", "Blau"]
farben.remove("Rot")
print(farben)

# %%
# Aufgabe 88: Leere Liste erstellen
kontakte = []
print(kontakte)

# %%
# Aufgabe 89: Inhalt prüfen
print("Admin" in ["User", "Admin", "Guest"])

# %%
# Aufgabe 90: Zahlen addieren
print(sum([1, 2, 3, 4]))

# %%
# Aufgabe 91: Zweites Element löschen
buchstaben = ["A", "B", "C"]
del buchstaben[1]
print(buchstaben)

# %%
# Aufgabe 92: Letztes Element entfernen
print([10, 20, 30].pop())

# %%
# Aufgabe 93: Variable in Liste
ip = "10.0.0.1"
ip_liste = [ip]
print(ip_liste)

# %%
# Aufgabe 94: Zwei Listen addieren
print([1, 2] + [3, 4])

# %%
# Aufgabe 95: Wert vervielfachen
print([0] * 5)

# %%
# Aufgabe 96: In String umwandeln
print(str([1, 2]))

# %%
# Aufgabe 97: Erstes Element überschreiben
x = [5, 6]
x[0] = sum(x)
print(x)

# %%
# Aufgabe 98: Teilliste ausgeben
print([1, 2, 3, 4][:2])

# %%
# Aufgabe 99: Datentyp von Liste
print(type([]))

# %%
# Aufgabe 100: Ganzzahlliste erstellen
zahlen = [1, 2, 3, 4, 5]
print(zahlen)

# %% [markdown]
# ### 20 Mittlere Aufgaben

# %%
# Aufgabe 101: Einschieben an Index
hardware = ["Tastatur", "Monitor"]
hardware.insert(1, "Maus")
print(hardware)

# %%
# Aufgabe 102: Element holen & löschen
server = ["S1", "S2", "S3"]
aktiv = server.pop(0)
print(aktiv, server)

# %%
# Aufgabe 103: Index suchen
print(["Maus", "Monitor", "Keyboard"].index("Monitor"))

# %%
# Aufgabe 104: Alphabetisch sortieren
os = ["Linux", "Windows", "MacOS"]
os.sort()
print(os)

# %%
# Aufgabe 105: Reihenfolge umdrehen
liste = ["A", "B", "C"]
liste.reverse()
print(liste)

# %%
# Aufgabe 106: Zählen von Vorkommen
print(["online", "offline", "online", "offline"].count("offline"))

# %%
# Aufgabe 107: Slicing Mitte
print([10, 20, 30, 40, 50][1:4])

# %%
# Aufgabe 108: Minimum ermitteln
print(min([1500, 1200, 1900, 1100]))

# %%
# Aufgabe 109: Maximum ermitteln
print(max([1500, 1200, 1900, 1100]))

# %%
# Aufgabe 110: Liste leeren
kontakte = ["Tim", "Jan"]
kontakte.clear()
print(kontakte)

# %%
# Aufgabe 111: Element austauschen
daten = [1, 2, 3]
daten[0], daten[-1] = daten[-1], daten[0]
print(daten)

# %%
# Aufgabe 112: Dynamische ToDo-Liste
todo_liste = []
todo_liste.append(input("Aufgabe: "))
print(todo_liste)

# %%
# Aufgabe 113: Verbinden mit Extend
l1 = [1, 2]
l1.extend([3, 4])
print(l1)

# %%
# Aufgabe 114: Prüfen und Löschen
liste = ["B", "C"]
if "A" in liste:
    liste.remove("A")  # Verhindert ValueError
print(liste)

# %%
# Aufgabe 115: Letzte 3 IPs
ips = ["IP1", "IP2", "IP3", "IP4", "IP5"]
print(ips[-3:])

# %%
# Aufgabe 116: Liste kopieren (Recherche)
a = [1, 2]
b = a.copy()
b.append(3)
print("a:", a)
print("b:", b)

# %%
# Aufgabe 117: Wert suchen und überschreiben
ordner = ["system", "temp", "data"]
idx = ordner.index("temp")
ordner[idx] = "cache"
print(ordner)

# %%
# Aufgabe 118: Durchschnitt ohne sum()
daten = [10, 20, 30]
print((daten[0] + daten[1] + daten[2]) / len(daten))

# %%
# Aufgabe 119: Sortieren rückwärts (Recherche)
zahlen = [5, 2, 9, 1]
zahlen.sort(reverse=True)
print(zahlen)

# %%
# Aufgabe 120: Liste schachteln
print([[1, 2], ["A", "B"]])

# %% [markdown]
# ---
# ## Thema 4: Debugging & Fehlersuche (40 Aufgaben)
#
# Jede Zelle enthält den fehlerhaften Code als Kommentar (zum Nachvollziehen des Fehlers) sowie direkt darunter den korrigierten, ausführbaren Code.
#
# ### 20 Einfache Aufgaben

# %%
# Aufgabe 121: Der String-Klammer-Bug
# Fehlerhaft:
# print("Hallo Welt

# Korrektur:
print("Hallo Welt")

# %%
# Aufgabe 122: Der Variablen-Schreibfehler
# Fehlerhaft:
# ip_adresse = "10.0.0.1"
# print(ip_adress)

# Korrektur:
ip_adresse = "10.0.0.1"
print(ip_adresse)

# %%
# Aufgabe 123: Der Typen-Verknüpfungs-Bug
# Fehlerhaft:
# print("Port: " + 80)

# Korrektur:
print("Port: " + "80")  # oder: print(f"Port: {80}")

# %%
# Aufgabe 124: Der falsche Anführungszeichen-Mix
# Fehlerhaft:
# print('Status: "online)

# Korrektur:
print('Status: "online"')

# %%
# Aufgabe 125: Der unvollständige f-String
# Fehlerhaft:
# name = "Webserver"
# print("Server-Name ist: {name}")

# Korrektur:
name = "Webserver"
print(f"Server-Name ist: {name}")

# %%
# Aufgabe 126: Der Input-Multiplikations-Bug
# Fehlerhaft:
# anzahl = input("Menge: ") # Eingabe: 5
# print(anzahl * 2) # Ausgabe ist 55, erwartet wird 10

# Korrektur:
anzahl = int(input("Menge: "))
print(anzahl * 2)

# %%
# Aufgabe 127: Der vergessene Punkt bei Methoden
# Fehlerhaft:
# print("test"upper())

# Korrektur:
print("test".upper())

# %%
# Aufgabe 128: Der Index-Out-Of-Range-Bug
# Fehlerhaft:
# server = ["SRV1", "SRV2"]
# print(server[2])

# Korrektur:
server = ["SRV1", "SRV2"]
print(server[1])

# %%
# Aufgabe 129: Der Groß-/Kleinschreibungs-Bug bei Boolean
# Fehlerhaft:
# aktiv = true

# Korrektur:
aktiv = True
print(aktiv)

# %%
# Aufgabe 130: Der fehlerhafte Float-Punkt
# Fehlerhaft:
# preis = 12,50

# Korrektur:
preis = 12.50
print(preis)

# %%
# Aufgabe 131: Variable vor Zuweisung genutzt
# Fehlerhaft:
# print(status)
# status = "Aktiv"

# Korrektur:
status = "Aktiv"
print(status)

# %%
# Aufgabe 132: Falsche Klammern bei Print
# Fehlerhaft:
# print "Willkommen"

# Korrektur:
print("Willkommen")

# %%
# Aufgabe 133: Zahl mit führender Null (SyntaxError)
# Fehlerhaft:
# port = 080

# Korrektur:
port = 80
print(port)

# %%
# Aufgabe 134: Vergessenes Komma in Liste
# Fehlerhaft:
# ip = ["10.0.0.1" "10.0.0.2"]

# Korrektur:
ip = ["10.0.0.1", "10.0.0.2"]
print(ip)

# %%
# Aufgabe 135: Addieren von Liste und String
# Fehlerhaft:
# liste = ["A", "B"]
# liste = liste + "C"

# Korrektur:
liste = ["A", "B"]
liste.append("C")
print(liste)

# %%
# Aufgabe 136: Falsches Escape-Zeichen (Pfad)
# Fehlerhaft:
# pfad = "C:\temp\newfile.txt"  # Verursacht Fehler wegen \t und \n

# Korrektur:
pfad = "C:\\temp\\newfile.txt"  # oder raw-string: r"C:\temp\newfile.txt"
print(pfad)

# %%
# Aufgabe 137: Großgeschriebenes Print
# Fehlerhaft:
# Print("Start")

# Korrektur:
print("Start")

# %%
# Aufgabe 138: Falsche Methodenschreibweise
# Fehlerhaft:
# print("abc".UPPER())

# Korrektur:
print("abc".upper())

# %%
# Aufgabe 139: Mathematische Operation auf Text
# Fehlerhaft:
# print("10" - 5)

# Korrektur:
print(int("10") - 5)

# %%
# Aufgabe 140: Fehlerhafte Variablenbenennung
# Fehlerhaft:
# 1_server = "SRV-01"

# Korrektur:
server_1 = "SRV-01"
print(server_1)

# %% [markdown]
# ### 20 Mittlere Aufgaben

# %%
# Aufgabe 141: Der ungültige Konvertierungs-Bug
# Fehlerhaft:
# wert = int("fünf")

# Korrektur:
wert = int("5")
print(wert)

# %%
# Aufgabe 142: Der Division-durch-Null-Bug
# Fehlerhaft:
# last, server = 100, 0
# schnitt = last / server

# Korrektur:
last, server = 100, 1
schnitt = last / server
print(schnitt)

# %%
# Aufgabe 143: Der String-Subtraktions-Bug
# Fehlerhaft:
# text = "ID-99"
# zahl = text - "ID-"

# Korrektur:
text = "ID-99"
zahl = text.replace("ID-", "")
print(zahl)

# %%
# Aufgabe 144: Der falsche Klammer-Typ bei Listen
# Fehlerhaft:
# daten = (1, 2, 3)  # Tuple statt Liste
# daten.append(4)

# Korrektur:
daten = [1, 2, 3]
daten.append(4)
print(daten)

# %%
# Aufgabe 145: Der fehlende Wert bei .remove()
# Fehlerhaft:
# daten = ["A", "B"]
# daten.remove()

# Korrektur:
daten = ["A", "B"]
daten.remove("A")
print(daten)

# %%
# Aufgabe 146: Der Doppel-Input-Klammer-Bug
# Fehlerhaft:
# anzahl = int(input("Anzahl: "

# Korrektur:
anzahl = int(input("Anzahl: "))
print(anzahl)

# %%
# Aufgabe 147: Der fehlerhafte List-Index-Zugriff
# Fehlerhaft:
# daten = [10, 20, 30]
# print(daten("1"))

# Korrektur:
daten = [10, 20, 30]
print(daten[1])

# %%
# Aufgabe 148: Der falsche f-String-Inhalt
# Fehlerhaft:
# rechner = "Client-01"
# print(f"Rechner ist rechner")

# Korrektur:
rechner = "Client-01"
print(f"Rechner ist {rechner}")

# %%
# Aufgabe 149: Der None-Rückgabe-Bug bei .sort()
# Fehlerhaft:
# liste = [3, 1, 2]
# sortierte_liste = liste.sort()
# print(sortierte_liste)  # Gibt None aus

# Korrektur:
liste = [3, 1, 2]
liste.sort()
print(liste)

# %%
# Aufgabe 150: Der unerwartete Einrückungs-Bug
# Fehlerhaft:
# print("Schritt 1")
#   print("Schritt 2")

# Korrektur:
print("Schritt 1")
print("Schritt 2")

# %%
# Aufgabe 151: Fehlerhaftes Format-Casting beim Input
# Fehlerhaft:
# preis = int(input("Preis: "))  # User gibt 19.99 ein -> Absturz
# print(preis)

# Korrektur:
preis = float(input("Preis: "))
print(preis)

# %%
# Aufgabe 152: Löschen von nicht existenten Listenelementen
# Fehlerhaft:
# users = ["Tim", "Jan"]
# users.remove("Ben")  # Absturz, da "Ben" nicht existiert

# Korrektur:
users = ["Tim", "Jan"]
if "Ben" in users:
    users.remove("Ben")
print(users)

# %%
# Aufgabe 153: Ungültige Methode für Datentyp
# Fehlerhaft:
# ip = 192.168
# print(ip.split("."))  # Absturz, da Float kein split() besitzt

# Korrektur:
ip = "192.168"
print(ip.split("."))

# %%
# Aufgabe 154: Gefangene Eingabe im f-String
# Fehlerhaft:
# print(f"Die Summe ist: {10 + "20"}")

# Korrektur:
print(f"Die Summe ist: {10 + int('20')}")

# %%
# Aufgabe 155: Index-Suche fehlgeschlagen
# Fehlerhaft:
# namen = ["Alex", "Ben"]
# idx = namen.index("Chris")  # Absturz, wenn "Chris" nicht da ist

# Korrektur:
namen = ["Alex", "Ben"]
idx = namen.index("Chris") if "Chris" in namen else -1
print(idx)

# %%
# Aufgabe 156: Zuweisungs-Gleichheits-Verwechslung
# Fehlerhaft:
# # Wir wollen prüfen, ob der Status "Aktiv" ist (Fehler bei der Zuweisung)
# status = "Inaktiv"
# status = "Aktiv"  # Sollte Prüfung sein

# Korrektur:
status = "Inaktiv"
print(status == "Aktiv")  # True/False Prüfung

# %%
# Aufgabe 157: Unlesbares Listen-Slicing
# Fehlerhaft:
# daten = [10, 20, 30]
# print(daten[1, 2])  # Falsche Syntax für Slicing

# Korrektur:
daten = [10, 20, 30]
print(daten[1:3])

# %%
# Aufgabe 158: Doppelter Operator-Fehler
# Fehlerhaft:
# rechnung = 10 ++ 5  # Kein direkter Absturz, aber logisch unschön

# Korrektur:
rechnung = 10 + 5
print(rechnung)

# %%
# Aufgabe 159: Falsche Syntax für String-Multiplikation
# Fehlerhaft:
# print("A" x 5)

# Korrektur:
print("A" * 5)

# %%
# Aufgabe 160: Nicht-String in .lower() Aufruf
# Fehlerhaft:
# code = 1024
# print(code.lower())  # Absturz, da Integer keine .lower()-Methode hat

# Korrektur:
code = "1024"
print(code.lower())

# %% [markdown]
# ---
# ## Ende des Wochen-Reviews
#
# Sicherung der Notebooks und Ausblick auf Woche 2 (Logik, Schleifen, Funktionen).
