# %% [markdown]
# # Tag 2: Benutzereingaben, Typkonvertierung & Fehler-Diagnose
#
# **Zeitrahmen:** 4 Stunden Vormittag (z. B. 09:00 – 13:00 Uhr)
# **Plattform:** Google Colab / Jupyter
# **Fokus:** Interaktive Skripte, gezielte Fehlerprovokation zur Fehlersuche und ein umfangreicher Pool an Programmieraufgaben.
#
# ---
#
# ## Zeitplan: Übersicht
#
# - **09:00 – 09:30 Uhr | Block 1:** Wiederholung & Festigung von Tag 1 (3 Aufgaben)
# - **09:30 – 10:15 Uhr | Block 2:** Benutzereingaben mit `input()` & Fehler-Sollbruchstelle 1
# - *10:15 – 10:30 Uhr | Pause*
# - **10:30 – 11:15 Uhr | Block 3:** Typkonvertierung & Fehler-Sollbruchstellen 2 & 3
# - **11:15 – 12:45 Uhr | Block 4:** Der große Übungs-Pool (12 Aufgaben, 4 Kategorien)
# - **12:45 – 13:00 Uhr | Block 5:** Analyse & Debugging-Sprechstunde
#
# > Jede Aufgabe steht in einer eigenen Code-Zelle und kann unabhängig ausgeführt werden.

# %% [markdown]
# ## 09:00 – 09:30 Uhr | Block 1: Wiederholung von Tag 1
#
# Zum Aufwärmen lösen die Teilnehmenden diese drei Aufgaben selbstständig. Sie dienen als Erinnerung an Variablen, Datentypen und f-Strings.
#
# ### Aufgabe W1: System-Statusbericht (Datentypen zuweisen)
# **Ziel:** Variablen korrekt anlegen und ausgeben.
# **Aufgabe:** Erstellen Sie folgende Variablen mit passenden Datentypen für ein IT-System:
# - `hostname`: Name des Servers (Text)
# - `cpu_cores`: Anzahl der CPU-Kerne (Ganzzahl)
# - `speicherauslastung`: Aktuelle RAM-Belegung in Prozent (Nachkommazahl)
# - `datenbank_laeuft`: Status der Datenbank (Wahrheitswert)
#
# Geben Sie die Werte zeilenweise mit `print()` aus.

# %%
# Aufgabe W1: System-Statusbericht
hostname = "srv-fileserver01"
cpu_cores = 8
speicherauslastung = 67.5
datenbank_laeuft = True

print(hostname)
print(cpu_cores)
print(speicherauslastung)
print(datenbank_laeuft)

# %% [markdown]
# ### Aufgabe W2: Die manuelle Preisberechnung
# **Ziel:** Mathematische Grundoperationen mit festen Variablen.
# **Aufgabe:** Eine Software-Lizenz kostet netto 120 Euro.
# - Erstellen Sie eine Variable `netto_preis` mit dem Wert `120`.
# - Erstellen Sie eine Variable `steuersatz` mit dem Wert `0.19`.
# - Berechnen Sie den Steuerbetrag und den Bruttopreis in separaten Variablen.
# - Geben Sie beide Ergebnisse aus.

# %%
# Aufgabe W2: Die manuelle Preisberechnung
netto_preis = 120
steuersatz = 0.19

steuerbetrag = netto_preis * steuersatz
brutto_preis = netto_preis + steuerbetrag

print(steuerbetrag)
print(brutto_preis)

# %% [markdown]
# ### Aufgabe W3: Steckbrief-Formatierung (f-String)
# **Ziel:** Variablen in Text einbetten.
# **Aufgabe:** Erstellen Sie die Variablen `mitarbeiter_name`, `personalnummer` und `rolle`. Geben Sie diese in einem einzigen, lesbaren Satz mithilfe eines f-Strings aus.

# %%
# Aufgabe W3: Steckbrief-Formatierung
mitarbeiter_name = "Julia Schmidt"
personalnummer = 4471
rolle = "Systemadministratorin"

print(f"{mitarbeiter_name} (Personalnummer {personalnummer}) arbeitet als {rolle}.")

# %% [markdown]
# ---
# ## 09:30 – 10:15 Uhr | Block 2: Benutzereingaben mit `input()` & Fehler-Sollbruchstelle 1
#
# ### 1. Das Konzept von `input()`
# Bisher waren alle Daten hart im Code codiert. Jetzt öffnen wir das Programm für den Anwender.
#
# - **Syntax:** `variable = input("Aufforderungstext")`
# - **Funktionsweise:** Python gibt den Text aus, stoppt die Programmausführung und wartet, bis der Benutzer Text eingibt und mit `Enter` bestätigt. Der eingegebene Text wird in der Variablen gespeichert.
#
# **Gemeinsames Live-Coding:**

# %%
benutzer = input("Bitte geben Sie Ihren Windows-Benutzernamen ein: ")
print(f"Eingabe registriert für Benutzer: {benutzer}")

# %% [markdown]
# ### 2. ⚡ Fehler-Sollbruchstelle 1: Der Additions-Absturz (TypeError)
# Wir provozieren nun ganz bewusst einen Fehler, um zu verstehen, was `input()` im Hintergrund tut.
#
# **Schritt 1:** Führen Sie die folgende Zelle aus. **Schritt 2:** Geben Sie bei der Abfrage `25` ein und drücken Sie `Enter`. **Schritt 3:** Analysieren Sie die rote Fehlermeldung.
#
# Erwartete Fehlermeldung:
# ```
# TypeError: can only concatenate str (not "int") to str
# ```
#
# **Fehler-Diagnose für die Teilnehmenden:**
# 1. **Was bedeutet `str`?** String (Text).
# 2. **Was bedeutet `int`?** Integer (Ganzzahl).
# 3. **Was bedeutet `concatenate`?** Verknüpfen/Aneinanderhängen.
# 4. **Die Ursache:** `input()` liefert *immer* einen String zurück, selbst wenn der Benutzer `25` eingibt. Für Python lautet die Rechnung: `"25" + 10`. Python weigert sich, Text und Zahl zu addieren.

# %%
# ⚡ Fehler-Sollbruchstelle 1 — bewusst fehlerhaft, bitte ausführen und Fehlermeldung lesen
alter = input("Wie alt bist du? ")
alter_in_zehn_jahren = alter + 10
print(alter_in_zehn_jahren)

# %% [markdown]
# ---
# ## 10:30 – 11:15 Uhr | Block 3: Typkonvertierung & Fehler-Sollbruchstellen 2 & 3
#
# ### 1. Die Typkonvertierung (Casting)
# Um den Fehler aus Block 2 zu beheben, müssen wir den String in eine Zahl umwandeln.
#
# - `int(variable)`: Versucht, den Inhalt in eine Ganzzahl zu konvertieren.
# - `float(variable)`: Versucht, den Inhalt in eine Nachkommazahl zu konvertieren.
#
# **Die Reparatur (Kompakte Schreibweise):**

# %%
# Wir schachteln die Befehle ineinander. Python arbeitet von innen nach außen.
alter = int(input("Wie alt bist du? "))
alter_in_zehn_jahren = alter + 10
print(f"In 10 Jahren bist du {alter_in_zehn_jahren} Jahre alt.")

# %% [markdown]
# ### 2. ⚡ Fehler-Sollbruchstelle 2: Die ungültige Zahl (ValueError)
# Was passiert, wenn der Benutzer keine Zahlen eingibt, obwohl das Programm eine Ganzzahl erwartet?
#
# **Schritt 1:** Führen Sie die Zelle unten aus. **Schritt 2:** Geben Sie bei der Abfrage das Wort `dreißig` (in Buchstaben) oder `Admin` ein. **Schritt 3:** Analysieren Sie die Fehlermeldung.
#
# Erwartete Fehlermeldung:
# ```
# ValueError: invalid literal for int() with base 10: 'dreißig'
# ```
#
# **Fehler-Diagnose:**
# 1. **ValueError:** Wert-Fehler.
# 2. **Die Ursache:** Der Befehl `int()` versucht, Buchstaben in eine mathematische Zahl umzuwandeln. Da das Wort `"dreißig"` keine Ziffern enthält, bricht Python ab. `int()` funktioniert nur, wenn der String wie eine Zahl aussieht (z. B. `"30"`).

# %%
# ⚡ Fehler-Sollbruchstelle 2 — bitte mit einem nicht-numerischen Wert ausführen (z. B. "dreißig")
alter = int(input("Wie alt bist du? "))
alter_in_zehn_jahren = alter + 10
print(f"In 10 Jahren bist du {alter_in_zehn_jahren} Jahre alt.")

# %% [markdown]
# ### 3. ⚡ Fehler-Sollbruchstelle 3: Die vergessene Klammer (SyntaxError)
# Durch das Schachteln von Funktionen wie `int(input(...))` müssen wir zwei Klammern öffnen und auch wieder zwei schließen.
#
# Erwartete Fehlermeldung:
# ```
# SyntaxError: unexpected EOF while parsing
# ```
# *(In moderneren Python-Versionen oft präziser: `SyntaxError: '(' was never closed`)*
#
# **Fehler-Diagnose:**
# 1. **SyntaxError:** Grammatikfehler.
# 2. **unexpected EOF (End of File):** Python hat das Ende der Datei erreicht, während es noch nach der schließenden Klammer `)` gesucht hat.
#
# *Hinweis: Da ein `SyntaxError` das Ausführen der Zelle komplett verhindert, ist der fehlerhafte Code unten als Kommentar hinterlegt. Zum Ausprobieren die `#` vor den beiden Zeilen entfernen und Zelle ausführen.*

# %%
# ⚡ Fehler-Sollbruchstelle 3 — Klammer entfernen zum Testen (führt zu SyntaxError)
# port = int(input("Geben Sie den Port ein (z. B. 80):"
# print(f"Port {port} wird geöffnet.")

# Korrigierte Version:
port = int(input("Geben Sie den Port ein (z. B. 80): "))
print(f"Port {port} wird geöffnet.")

# %% [markdown]
# ---
# ## 11:15 – 12:45 Uhr | Block 4: Der große Übungs-Pool
#
# Schnellere Teilnehmende können alle Aufgaben lösen, während langsamere Teilnehmende sich auf die Kategorien A und B konzentrieren.
#
# ### Kategorie A: Reine Text-Interaktion (Kein Casting nötig)
#
# #### Aufgabe 1: Der Begrüßungs-Generator
# Fragen Sie den Benutzer nach seinem Vornamen und seiner Stadt. Geben Sie einen Satz aus wie: `Hallo [Vorname], wie ist das Wetter in [Stadt]?`.

# %%
# Aufgabe 1: Der Begrüßungs-Generator
vorname = input("Vorname: ")
stadt = input("Stadt: ")
print(f"Hallo {vorname}, wie ist das Wetter in {stadt}?")

# %% [markdown]
# #### Aufgabe 2: AD-Gruppen-Zuweisung
# Schreiben Sie ein Skript, das einen Benutzernamen abfragt. Das Skript soll den Benutzer fiktiv der Gruppe "Domain-Admins" hinzufügen und das Ergebnis ausgeben.
#
# Erwartete Ausgabe bei Eingabe `t.mueller`:
# `Benutzer t.mueller wurde erfolgreich zur Gruppe 'Domain-Admins' hinzugefügt.`

# %%
# Aufgabe 2: AD-Gruppen-Zuweisung
username = input("Windows-Benutzername: ")
print(f"Benutzer {username} wurde erfolgreich zur Gruppe 'Domain-Admins' hinzugefügt.")

# %% [markdown]
# #### Aufgabe 3: E-Mail-Generator
# Fragen Sie den Vornamen, den Nachnamen und die Firmen-Domain (z. B. `firma.de`) ab. Erzeugen Sie daraus eine E-Mail-Adresse im Format `vorname.nachname@domain`.

# %%
# Aufgabe 3: E-Mail-Generator
vorname = input("Vorname: ")
nachname = input("Nachname: ")
domain = input("Domain (z. B. firma.de): ")
print(f"E-Mail-Adresse: {vorname}.{nachname}@{domain}")

# %% [markdown]
# ### Kategorie B: Ganzzahl-Berechnungen (int-Casting erforderlich)
#
# #### Aufgabe 4: Der Verdoppler
# Fragen Sie den Benutzer nach einer Ganzzahl. Multiplizieren Sie diese Zahl mit 2 und geben Sie das Ergebnis aus.

# %%
# Aufgabe 4: Der Verdoppler
zahl = int(input("Geben Sie eine Ganzzahl ein: "))
ergebnis = zahl * 2
print(f"Das Doppelte ist: {ergebnis}")

# %% [markdown]
# #### Aufgabe 5: Server-Rack-Planer
# Ein Standard-Server-Rack hat 42 Höheneinheiten (HE). Fragen Sie den Benutzer, wie viele Höheneinheiten bereits durch Server belegt sind. Berechnen Sie, wie viele Höheneinheiten noch frei sind.

# %%
# Aufgabe 5: Server-Rack-Planer
belegt = int(input("Wie viele HE sind bereits belegt? "))
frei = 42 - belegt
print(f"Es sind noch {frei} Höheneinheiten im Rack frei.")

# %% [markdown]
# #### Aufgabe 6: Jahresgehalt-Rechner
# Fragen Sie nach dem monatlichen Bruttogehalt. Berechnen Sie das Jahresgehalt (Monatsgehalt mal 12) und geben Sie es aus.

# %%
# Aufgabe 6: Jahresgehalt-Rechner
monatsgehalt = int(input("Monatliches Bruttogehalt in Euro: "))
jahresgehalt = monatsgehalt * 12
print(f"Das Jahresgehalt beträgt {jahresgehalt} Euro.")

# %% [markdown]
# #### Aufgabe 7: Tage in Stunden umrechnen
# Fragen Sie den Benutzer nach einer Anzahl von Tagen (z. B. für eine Server-Uptime). Berechnen Sie, wie vielen Stunden das entspricht.

# %%
# Aufgabe 7: Tage in Stunden umrechnen
tage = int(input("Anzahl der Tage: "))
stunden = tage * 24
print(f"{tage} Tage entsprechen genau {stunden} Stunden.")

# %% [markdown]
# ### Kategorie C: Nachkommastellen-Berechnungen (float-Casting erforderlich)
#
# #### Aufgabe 8: Mehrwertsteuer-Addierer
# Fragen Sie den Benutzer nach einem Netto-Preis (z. B. `45.90`). Berechnen Sie den Brutto-Preis inklusive 19% Mehrwertsteuer (Netto-Preis mal 1.19) und geben Sie ihn aus.

# %%
# Aufgabe 8: Mehrwertsteuer-Addierer
netto = float(input("Netto-Preis in Euro (mit Punkt statt Komma): "))
brutto = netto * 1.19
print(f"Der Brutto-Preis beträgt {brutto} Euro.")

# %% [markdown]
# #### Aufgabe 9: RAM-Preiskalkulator
# Ein Gigabyte RAM kostet aktuell 4.50 Euro. Fragen Sie den Benutzer, wie viel GB RAM er bestellen möchte (z. B. `16` oder `32`). Berechnen Sie den Gesamtpreis.

# %%
# Aufgabe 9: RAM-Preiskalkulator
ram_gb = float(input("Wie viel GB RAM werden benötigt? "))
preis = ram_gb * 4.50
print(f"Der Preis für {ram_gb} GB RAM beträgt {preis} Euro.")

# %% [markdown]
# #### Aufgabe 10: Temperatur-Konverter (Fahrenheit in Celsius)
# Ein US-amerikanischer Serverraum meldet die Temperatur in Fahrenheit. Fragen Sie den Benutzer nach der Temperatur in Fahrenheit. Rechnen Sie diese in Celsius um.
#
# *Formel:* Celsius = (Fahrenheit − 32) × 5/9

# %%
# Aufgabe 10: Temperatur-Konverter (Fahrenheit in Celsius)
fahrenheit = float(input("Temperatur in Fahrenheit: "))
celsius = (fahrenheit - 32) * 5 / 9
print(f"{fahrenheit} Grad Fahrenheit entsprechen {celsius} Grad Celsius.")

# %% [markdown]
# ### Kategorie D: IT-Support-Szenarien (Herausforderung)
#
# #### Aufgabe 11: IP-Subnetz Host-Rechner
# In einem Subnetz bestimmt die CIDR-Schnittmaske die Anzahl der IPs. Die Formel für nutzbare Hosts lautet: 2^(freie Bits) − 2.
# - Fragen Sie den Benutzer nach den freien Bits (z. B. `8` bei einer /24 Maske).
# - Berechnen Sie die nutzbaren Hosts.
# - *Hinweis:* Potenzieren in Python funktioniert mit `**` (z. B. `2 ** 8`).

# %%
# Aufgabe 11: IP-Subnetz Host-Rechner
freie_bits = int(input("Geben Sie die freien Host-Bits ein (z. B. 8): "))
nutzbare_hosts = (2 ** freie_bits) - 2
print(f"In diesem Subnetz gibt es {nutzbare_hosts} nutzbare IP-Adressen.")

# %% [markdown]
# #### Aufgabe 12: IT-Budget-Aufteilung
# Eine IT-Abteilung erhält ein Budget (z. B. `50000` Euro), das zu gleichen Teilen auf eine bestimmte Anzahl von Projekten aufgeteilt werden soll.
# - Fragen Sie nach dem Gesamtbudget (Ganzzahl).
# - Fragen Sie nach der Anzahl der Projekte (Ganzzahl).
# - Berechnen Sie den Betrag pro Projekt (Ganzzahldivision `//`).
# - Berechnen Sie den verbleibenden Restbetrag, der nicht gleichmäßig aufgeteilt werden kann (Modulo `%`).

# %%
# Aufgabe 12: IT-Budget-Aufteilung
budget = int(input("Gesamtbudget der IT-Abteilung: "))
projekte = int(input("Anzahl der Projekte: "))

betrag_pro_projekt = budget // projekte
restbetrag = budget % projekte

print(f"Jedes Projekt erhält: {betrag_pro_projekt} Euro.")
print(f"Nicht aufteilbarer Restbetrag: {restbetrag} Euro.")

# %% [markdown]
# ---
# ## 12:45 – 13:00 Uhr | Block 5: Analyse & Debugging-Sprechstunde
#
# Zum Ende des Vormittags kommen alle Teilnehmenden im Plenum zusammen.
#
# - **Der "Erfolgsmoment":** Ein oder zwei Teilnehmende präsentieren ihre Lösung zu einer der schwereren Aufgaben (z. B. Aufgabe 11 oder 12) direkt im Notebook.
# - **Fehler-Review:** Typische Fälle aus der Praxisphase:
#   - Fehlerhafter Umgang mit Punkten und Kommas bei `float`.
#   - Vergessene Umwandlung von Strings bei mathematischen Berechnungen.
# - **Sicherung:** Die Teilnehmenden werden daran erinnert, ihr Notebook abzuspeichern, um die Code-Beispiele als Referenz für die nächsten Tage zur Hand zu haben.
